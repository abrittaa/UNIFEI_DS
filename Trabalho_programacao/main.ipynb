# %%
from CRUD import adicionar_produto, remover_produto, atualizar_produto, buscar_produto, listar_produtos

# %%
def exibir_menu():
    print("\n===== SISTEMA DE INVENTÁRIO =====")
    print("1. Adicionar produto")
    print("2. Remover produto")
    print("3. Atualizar produto")
    print("4. Buscar produto")
    print("5. Listar produtos")
    print("0. Sair")
    print("=================================")

def main():
    produtos = []  # lista que guarda tudo em memória

    while True:
        exibir_menu()
        opcao = input("Escolha uma opção: ").strip()

        if opcao == "1":
            adicionar_produto(produtos)
        elif opcao == "2":
            remover_produto(produtos)
        elif opcao == "3":
            atualizar_produto(produtos)
        elif opcao == "4":
            buscar_produto(produtos)
        elif opcao == "5":
            listar_produtos(produtos)
        elif opcao == "0":
            print("Encerrando o sistema. Até logo!")
            break
        else:
            print("Opção inválida! Tente novamente.")

if __name__ == "__main__":
    main()
# Out:
# ===== SISTEMA DE INVENTÁRIO =====
# 1. Adicionar produto
# 2. Remover produto
# 3. Atualizar produto
# 4. Buscar produto
# 5. Listar produtos
# 0. Sair
# =================================
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 35
#      32             print("Opção inválida! Tente novamente.")
#      34 if __name__ == "__main__":
# ---> 35     main()
#
# Cell In[4], line 19, in main()
#      16 opcao = input("Escolha uma opção: ").strip()
#      18 if opcao == "1":
# ---> 19     adicionar_produto(produtos)
#      20 elif opcao == "2":
#      21     remover_produto(produtos)
#
# File c:\UNIFEI_DS\Trabalho_programacao\CRUD.py:3, in adicionar_produto(produtos)
#       1 def adicionar_produto(produtos):
#       2     nome = input("Digite o nome do produto: ")
# ----> 3     preco = float(input("Digite o preço do produto: R$ "))
#       4     quantidade = int(input("Digite a quantidade em estoque: "))
#       5     produtos.append({"nome": nome, "preco": preco, "quantidade": quantidade})
#
# ValueError: could not convert string to float: '-'
